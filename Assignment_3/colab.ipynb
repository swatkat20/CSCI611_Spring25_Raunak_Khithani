# %%
pip install ultralytics opencv-python numpy torch torchvision torchaudio
# Out:
# ...
#   Using cached ultralytics-8.3.93-py3-none-any.whl.metadata (35 kB)
# ...
#   Using cached opencv_python-4.11.0.86-cp37-abi3-macosx_13_0_arm64.whl.metadata (20 kB)
# ...
#   Using cached numpy-2.2.4-cp312-cp312-macosx_14_0_arm64.whl.metadata (62 kB)
# ...
#   Using cached torch-2.6.0-cp312-none-macosx_11_0_arm64.whl.metadata (28 kB)
# ...
#   Using cached torchvision-0.21.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.1 kB)
# ...
#   Using cached torchaudio-2.6.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.6 kB)
# ...
#   Using cached numpy-2.1.1-cp312-cp312-macosx_14_0_arm64.whl.metadata (60 kB)
# ...
#   Using cached matplotlib-3.10.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (11 kB)
# ...
#   Using cached pillow-11.1.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.1 kB)
# ...
#   Using cached PyYAML-6.0.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.1 kB)
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached scipy-1.15.2-cp312-cp312-macosx_14_0_arm64.whl.metadata (61 kB)
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")
model.train(data="ts_data.yaml", epochs=20, imgsz=320, batch=16)
# Out:
# New https://pypi.org/project/ultralytics/8.3.92 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.91 🚀 Python-3.10.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100 80GB PCIe, 81051MiB)
# ...

# %%
subOptModel = YOLO("/Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/runs/detect/train/weights/best.pt")
#results = subOptModel("/research/rkhithani/assignment3/archive/testVideos/GX011159.MP4")
results = subOptModel("/Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/archive/testVideos/GX011159.MP4", save=True, stream=True)  # Process video, save output, and stream results
for r in results:
        boxes = r.boxes  # Boxes object for bbox outputs
        masks = r.masks  # Masks object for segment masks outputs
        probs = r.probs  # Class probabilities for classification outputs
# Out:
# video 1/1 (frame 1/973) /Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/archive/testVideos/GX011159.MP4: 192x320 1 mandatory, 20.6ms
# video 1/1 (frame 2/973) /Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/archive/testVideos/GX011159.MP4: 192x320 1 mandatory, 28.9ms
# video 1/1 (frame 3/973) /Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/archive/testVideos/GX011159.MP4: 192x320 1 mandatory, 20.1ms
# video 1/1 (frame 4/973) /Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/archive/testVideos/GX011159.MP4: 192x320 1 mandatory, 19.0ms
# video 1/1 (frame 5/973) /Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/archive/testVideos/GX011159.MP4: 192x320 1 mandatory, 20.1ms
# video 1/1 (frame 6/973) /Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/archive/testVideos/GX011159.MP4: 192x320 1 mandatory, 15.9ms
# ...

# %%
subOptModel = YOLO("/Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/runs/detect/train/weights/best.pt")
#results = subOptModel("/research/rkhithani/assignment3/archive/testVideos/GX011159.MP4")
results = subOptModel("/Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/archive/testVideos/output.MP4", save=True, stream=True)  # Process video, save output, and stream results
for r in results:
        boxes = r.boxes  # Boxes object for bbox outputs
        masks = r.masks  # Masks object for segment masks outputs
        probs = r.probs  # Class probabilities for classification outputs
# Out:
# video 1/1 (frame 1/508) /Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/archive/testVideos/output.MP4: 320x320 (no detections), 50.1ms
# video 1/1 (frame 2/508) /Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/archive/testVideos/output.MP4: 320x320 (no detections), 30.5ms
# video 1/1 (frame 3/508) /Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/archive/testVideos/output.MP4: 320x320 (no detections), 23.4ms
# video 1/1 (frame 4/508) /Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/archive/testVideos/output.MP4: 320x320 (no detections), 22.8ms
# video 1/1 (frame 5/508) /Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/archive/testVideos/output.MP4: 320x320 1 prohibitory, 29.8ms
# video 1/1 (frame 6/508) /Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/archive/testVideos/output.MP4: 320x320 1 prohibitory, 17.9ms
# ...

# %%
model = YOLO("yolov8n.pt")
model.train(
    data="ts_data.yaml",
    epochs=80,          
    imgsz=1280,        
    batch=32,           
    momentum=0.937,     
    augment=True,     
    multi_scale=True,   
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.92 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.91 🚀 Python-3.10.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100 80GB PCIe, 81051MiB)
# ...

# %%
optimized_model = YOLO("/Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/runs/detect/train2/weights/best.pt")
results = optimized_model("/Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/archive/testVideos/GX011159.MP4",conf = 0.5,save=True, stream=True)
for r in results:
        boxes = r.boxes  # Boxes object for bbox outputs
        masks = r.masks  # Masks object for segment masks outputs
        probs = r.probs  # Class probabilities for classification outputs
# Out:
# video 1/1 (frame 1/973) /Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/archive/testVideos/GX011159.MP4: 736x1280 1 other, 150.4ms
# video 1/1 (frame 2/973) /Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/archive/testVideos/GX011159.MP4: 736x1280 1 other, 156.1ms
# video 1/1 (frame 3/973) /Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/archive/testVideos/GX011159.MP4: 736x1280 1 other, 150.6ms
# video 1/1 (frame 4/973) /Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/archive/testVideos/GX011159.MP4: 736x1280 1 other, 138.7ms
# video 1/1 (frame 5/973) /Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/archive/testVideos/GX011159.MP4: 736x1280 1 other, 144.7ms
# video 1/1 (frame 6/973) /Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/archive/testVideos/GX011159.MP4: 736x1280 (no detections), 150.9ms
# ...

# %%
optimized_model = YOLO("/Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/runs/detect/train2/weights/best.pt")
results = optimized_model("/Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/archive/testVideos/output.MP4",conf = 0.5,save=True, stream=True)
for r in results:
        boxes = r.boxes  # Boxes object for bbox outputs
        masks = r.masks  # Masks object for segment masks outputs
        probs = r.probs  # Class probabilities for classification outputs
# Out:
# video 1/1 (frame 1/508) /Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/archive/testVideos/output.MP4: 1280x1280 (no detections), 301.3ms
# video 1/1 (frame 2/508) /Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/archive/testVideos/output.MP4: 1280x1280 (no detections), 271.3ms
# video 1/1 (frame 3/508) /Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/archive/testVideos/output.MP4: 1280x1280 (no detections), 261.8ms
# video 1/1 (frame 4/508) /Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/archive/testVideos/output.MP4: 1280x1280 (no detections), 252.3ms
# video 1/1 (frame 5/508) /Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/archive/testVideos/output.MP4: 1280x1280 (no detections), 238.4ms
# video 1/1 (frame 6/508) /Users/rauankkhithani/Desktop/MS/608-DataScience/611/assignment3/archive/testVideos/output.MP4: 1280x1280 (no detections), 240.9ms
# ...
